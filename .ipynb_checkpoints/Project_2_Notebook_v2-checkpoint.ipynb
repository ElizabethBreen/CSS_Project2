# %% [markdown]
# # Project 2 Team 7
#
# ### Diana Casanova, Renata Barreto, and Elizabeth Breen

# %% [markdown]
# Which U.S. counties should we prioritize to receive a diabetes intervention?
#
# To answer this question, we will analyze the data provided using Machine Learning techniques. Theoretically, these techniques will allow us to not only identify places with the greatest current burden of diabetes, but also to predict where the burden of diabetes will be highest in the future. Places with the greatest burden of diabetes may benefit the most from the diabetes intervention considered by policy makers.
#
# First, we import our libraries and data:

# %% [markdown]
# ## Setup

# %%
import numpy as np
import datetime as dt
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Ridge, Lasso, LinearRegression
from sklearn.model_selection import KFold
from sklearn.model_selection import GridSearchCV

sns.set_style("darkgrid")

# %%
diabetes = pd.read_csv('Diabetes with Population Info by County 2017.csv')

# %% [markdown]
# ## Exploratory Data Analysis
#
# Next, we take stock of the data: What does it look like? What format is it in? How large is it? What kinds of information is provided?

# %%
diabetes.head()
# Out:
#            County    State  CountyFIPS Diabetes_Number Obesity_Number  \
# 0  Autauga County  Alabama        1001            5178          13489
# 1  Baldwin County  Alabama        1003           16707          48542
# 2  Barbour County  Alabama        1005            3400           8009
# 3     Bibb County  Alabama        1007            2371           6534
# 4   Blount County  Alabama        1009            6282          14227
#
#   Physical_Inactivity_Number  \
# 0                      12525
# 1                      40024
# 2                       5431
# 3                       5827
# 4                      14365
#
#   sex and age_total population_65 years and over_sex ratio (males per 100 females)  \
# 0                                               76.5
# 1                                               86.6
# 2                                               76.2
# 3                                               80.5
# 4                                               79.7
#
#    race_total population  race_total population_one race  \
# 0                  55200                           54170
# 1                 208107                          204535
# 2                  25782                           25429
# 3                  22527                           22340
# 4                  57645                           56710
#
#    race_total population_two or more races  ...  \
# 0                                     1030  ...
# 1                                     3572  ...
# 2                                      353  ...
# 3                                      187  ...
# 4                                      935  ...
#
#    sex and age_total population_21 years and over  \
# 0                                           39614
# 1                                          155502
# 2                                           19394
# 3                                           16864
# 4                                           42232
#
#    sex and age_total population_62 years and over  \
# 0                                            9403
# 1                                           49811
# 2                                            5658
# 3                                            4323
# 4                                           12400
#
#    sex and age_total population_65 years and over  \
# 0                                            8050
# 1                                           40665
# 2                                            4634
# 3                                            3661
# 4                                           10233
#
#    sex and age_total population_18 years and over_1  \
# 0                                             41831
# 1                                            162430
# 2                                             20346
# 3                                             17868
# 4                                             44177
#
#    sex and age_total population_18 years and over_male  \
# 0                                              20054
# 1                                              78104
# 2                                              10923
# 3                                               9578
# 4                                              21595
#
#    sex and age_total population_18 years and over_female  \
# 0                                              21777
# 1                                              84326
# 2                                               9423
# 3                                               8290
# 4                                              22582
#
#    sex and age_total population_18 years and over_sex ratio (males per 100 females)  \
# 0                                               92.1
# 1                                               92.6
# 2                                              115.9
# 3                                              115.5
# 4                                               95.6
#
#    sex and age_total population_65 years and over_1  \
# 0                                              8050
# 1                                             40665
# 2                                              4634
# 3                                              3661
# 4                                             10233
#
#    sex and age_total population_65 years and over_male  \
# 0                                               3488
# 1                                              18870
# 2                                               2004
# 3                                               1633
# 4                                               4540
#
#    sex and age_total population_65 years and over_female
# 0                                               4562
# 1                                              21795
# 2                                               2630
# 3                                               2028
# 4                                               5693
#
# [5 rows x 95 columns]

# %%
diabetes.shape
# Out:
# (3220, 95)

# %%
diabetes.describe()
# Out:
#          CountyFIPS  race_total population  race_total population_one race  \
# count   3220.000000           3.220000e+03                    3.220000e+03
# mean   31393.605280           1.013323e+05                    9.803687e+04
# std    16292.078954           3.260964e+05                    3.142309e+05
# min     1001.000000           7.500000e+01                    6.000000e+01
# 25%    19032.500000           1.121425e+04                    1.090100e+04
# 50%    30024.000000           2.595050e+04                    2.537900e+04
# 75%    46105.500000           6.655225e+04                    6.497525e+04
# max    72153.000000           1.009805e+07                    9.700372e+06
#
#        race_total population_two or more races  \
# count                              3220.000000
# mean                               3295.423292
# std                               13032.711931
# min                                   0.000000
# 25%                                 169.750000
# 50%                                 492.000000
# 75%                                1742.500000
# max                              397680.000000
#
#        race_total population_one race_1  race_total population_one race_white  \
# count                      3.220000e+03                          3.220000e+03
# mean                       9.803687e+04                          7.366104e+04
# std                        3.142309e+05                          2.012548e+05
# min                        6.000000e+01                          1.600000e+01
# 25%                        1.090100e+04                          9.050250e+03
# 50%                        2.537900e+04                          2.161750e+04
# 75%                        6.497525e+04                          5.711775e+04
# max                        9.700372e+06                          5.186859e+06
#
#        race_total population_one race_black or african american  \
# count                                       3.220000e+03
# mean                                        1.282022e+04
# std                                         5.514027e+04
# min                                         0.000000e+00
# 25%                                         1.167500e+02
# 50%                                         8.380000e+02
# 75%                                         5.591000e+03
# max                                         1.230494e+06
#
#        race_total population_one race_american indian and alaska native  \
# count                                        3220.000000
# mean                                          840.862422
# std                                          3534.196512
# min                                             0.000000
# 25%                                            30.000000
# 50%                                           114.000000
# 75%                                           425.250000
# max                                         82699.000000
#
#        race_total population_one race_american indian and alaska native_cherokee tribal grouping  \
# count                                        3220.000000
# mean                                           90.346894
# std                                           534.021931
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             9.000000
# 75%                                            48.000000
# max                                         14104.000000
#
#        race_total population_one race_american indian and alaska native_chippewa tribal grouping  \
# count                                        3220.000000
# mean                                           36.718634
# std                                           300.672832
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             6.000000
# max                                         10609.000000
#
#        ...  sex and age_total population_21 years and over  \
# count  ...                                    3.220000e+03
# mean   ...                                    7.412272e+04
# std    ...                                    2.384994e+05
# min    ...                                    6.900000e+01
# 25%    ...                                    8.314250e+03
# 50%    ...                                    1.936550e+04
# 75%    ...                                    4.906400e+04
# max    ...                                    7.433332e+06
#
#        sex and age_total population_62 years and over  \
# count                                    3.220000e+03
# mean                                     1.906676e+04
# std                                      5.470009e+04
# min                                      1.900000e+01
# 25%                                      2.583750e+03
# 50%                                      5.704500e+03
# 75%                                      1.435650e+04
# max                                      1.610630e+06
#
#        sex and age_total population_65 years and over  \
# count                                    3.220000e+03
# mean                                     1.549044e+04
# std                                      4.432602e+04
# min                                      1.200000e+01
# 25%                                      2.111500e+03
# 50%                                      4.698500e+03
# 75%                                      1.171375e+04
# max                                      1.299277e+06
#
#        sex and age_total population_18 years and over_1  \
# count                                      3.220000e+03
# mean                                       7.827602e+04
# std                                        2.513513e+05
# min                                        7.100000e+01
# 25%                                        8.691500e+03
# 50%                                        2.026050e+04
# 75%                                        5.200525e+04
# max                                        7.851531e+06
#
#        sex and age_total population_18 years and over_male  \
# count                                       3.220000e+03
# mean                                        3.809320e+04
# std                                         1.220023e+05
# min                                         3.600000e+01
# 25%                                         4.355250e+03
# 50%                                         9.997500e+03
# 75%                                         2.557400e+04
# max                                         3.827779e+06
#
#        sex and age_total population_18 years and over_female  \
# count                                       3.220000e+03
# mean                                        4.018282e+04
# std                                         1.293948e+05
# min                                         3.100000e+01
# 25%                                         4.285250e+03
# 50%                                         1.019050e+04
# 75%                                         2.664950e+04
# max                                         4.023752e+06
#
#        sex and age_total population_18 years and over_sex ratio (males per 100 females)  \
# count                                        3220.000000
# mean                                           99.439317
# std                                            14.740158
# min                                            70.800000
# 25%                                            93.000000
# 50%                                            96.500000
# 75%                                           100.800000
# max                                           414.700000
#
#        sex and age_total population_65 years and over_1  \
# count                                      3.220000e+03
# mean                                       1.549044e+04
# std                                        4.432602e+04
# min                                        1.200000e+01
# 25%                                        2.111500e+03
# 50%                                        4.698500e+03
# 75%                                        1.171375e+04
# max                                        1.299277e+06
#
#        sex and age_total population_65 years and over_male  \
# count                                        3220.000000
# mean                                         6850.940683
# std                                         19234.567636
# min                                             0.000000
# 25%                                           984.750000
# 50%                                          2129.500000
# 75%                                          5234.000000
# max                                        561006.000000
#
#        sex and age_total population_65 years and over_female
# count                                        3220.000000
# mean                                         8639.495342
# std                                         25111.933583
# min                                            10.000000
# 25%                                          1126.000000
# 50%                                          2548.000000
# 75%                                          6314.500000
# max                                        738271.000000
#
# [8 rows x 89 columns]

# %%
diabetes.dtypes
# Out:
# County                                                                               object
# State                                                                                object
# CountyFIPS                                                                            int64
# Diabetes_Number                                                                      object
# Obesity_Number                                                                       object
#                                                                                      ...
# sex and age_total population_18 years and over_female                                 int64
# sex and age_total population_18 years and over_sex ratio (males per 100 females)    float64
# sex and age_total population_65 years and over_1                                      int64
# sex and age_total population_65 years and over_male                                   int64
# sex and age_total population_65 years and over_female                                 int64
# Length: 95, dtype: object

# %% [markdown]
# ## Data Preprocessing

# %%
diabetes.isnull().sum()
# Out:
# County                                                                              0
# State                                                                               0
# CountyFIPS                                                                          0
# Diabetes_Number                                                                     0
# Obesity_Number                                                                      0
#                                                                                    ..
# sex and age_total population_18 years and over_female                               0
# sex and age_total population_18 years and over_sex ratio (males per 100 females)    0
# sex and age_total population_65 years and over_1                                    0
# sex and age_total population_65 years and over_male                                 0
# sex and age_total population_65 years and over_female                               0
# Length: 95, dtype: int64

# %%
# convert strings to numeric data types

diabetes = diabetes.apply(pd.to_numeric, errors = 'coerce')
diabetes.head()

# create proportions by sex

#create proportions by sex
diabetes['male_over_18']=diabetes['sex and age_total population_18 years and over_male']/diabetes['sex and age_total population_18 years and over']
diabetes['female_over_18']=diabetes['sex and age_total population_18 years and over_female']/diabetes['sex and age_total population_18 years and over']

# %% [markdown]
# Remove the County and State names from the data

# %%
diabetes = diabetes.drop(['County', 'State'], axis = 1)
diabetes.head()
# Out:
#    CountyFIPS  Diabetes_Number  Obesity_Number  Physical_Inactivity_Number  \
# 0        1001           5178.0         13489.0                     12525.0
# 1        1003          16707.0         48542.0                     40024.0
# 2        1005           3400.0          8009.0                      5431.0
# 3        1007           2371.0          6534.0                      5827.0
# 4        1009           6282.0         14227.0                     14365.0
#
#    sex and age_total population_65 years and over_sex ratio (males per 100 females)  \
# 0                                               76.5
# 1                                               86.6
# 2                                               76.2
# 3                                               80.5
# 4                                               79.7
#
#    race_total population  race_total population_one race  \
# 0                  55200                           54170
# 1                 208107                          204535
# 2                  25782                           25429
# 3                  22527                           22340
# 4                  57645                           56710
#
#    race_total population_two or more races  race_total population_one race_1  \
# 0                                     1030                             54170
# 1                                     3572                            204535
# 2                                      353                             25429
# 3                                      187                             22340
# 4                                      935                             56710
#
#    race_total population_one race_white  ...  \
# 0                                 42437  ...
# 1                                179526  ...
# 2                                 12216  ...
# 3                                 17268  ...
# 4                                 55054  ...
#
#    sex and age_total population_65 years and over  \
# 0                                            8050
# 1                                           40665
# 2                                            4634
# 3                                            3661
# 4                                           10233
#
#    sex and age_total population_18 years and over_1  \
# 0                                             41831
# 1                                            162430
# 2                                             20346
# 3                                             17868
# 4                                             44177
#
#    sex and age_total population_18 years and over_male  \
# 0                                              20054
# 1                                              78104
# 2                                              10923
# 3                                               9578
# 4                                              21595
#
#    sex and age_total population_18 years and over_female  \
# 0                                              21777
# 1                                              84326
# 2                                               9423
# 3                                               8290
# 4                                              22582
#
#    sex and age_total population_18 years and over_sex ratio (males per 100 females)  \
# 0                                               92.1
# 1                                               92.6
# 2                                              115.9
# 3                                              115.5
# 4                                               95.6
#
#    sex and age_total population_65 years and over_1  \
# 0                                              8050
# 1                                             40665
# 2                                              4634
# 3                                              3661
# 4                                             10233
#
#    sex and age_total population_65 years and over_male  \
# 0                                               3488
# 1                                              18870
# 2                                               2004
# 3                                               1633
# 4                                               4540
#
#    sex and age_total population_65 years and over_female  male_over_18  \
# 0                                               4562          0.479405
# 1                                              21795          0.480847
# 2                                               2630          0.536862
# 3                                               2028          0.536042
# 4                                               5693          0.488829
#
#    female_over_18
# 0        0.520595
# 1        0.519153
# 2        0.463138
# 3        0.463958
# 4        0.511171
#
# [5 rows x 95 columns]

# %%
diabetes_nomiss=diabetes.dropna()

# %%
diabetes_nomiss.shape
# Out:
# (3112, 95)

# %%
diabetes_nomiss.dtypes
# Out:
# CountyFIPS                                                                            int64
# Diabetes_Number                                                                     float64
# Obesity_Number                                                                      float64
# Physical_Inactivity_Number                                                          float64
# sex and age_total population_65 years and over_sex ratio (males per 100 females)    float64
#                                                                                      ...
# sex and age_total population_65 years and over_1                                      int64
# sex and age_total population_65 years and over_male                                   int64
# sex and age_total population_65 years and over_female                                 int64
# male_over_18                                                                        float64
# female_over_18                                                                      float64
# Length: 95, dtype: object

# %%
diabetes_rates = diabetes_nomiss.drop (["CountyFIPS", "race_total population"], axis = 1).div(diabetes_nomiss['race_total population'], axis = "index")
diabetes_rates['CountyFIPS'] = diabetes_nomiss['CountyFIPS']
diabetes_rates['race_total population'] = diabetes_nomiss['race_total population']


# reconstruct rates by sex

diabetes_rates['male_18_adj'] = diabetes_rates['male_over_18']*diabetes['race_total population']
diabetes_rates['female_18_adj'] = diabetes_rates['female_over_18']*diabetes['race_total population']

# %%
diabetes_rates.shape
# Out:
# (3112, 97)

# %%
diabetes_rates.head()
# Out:
#    Diabetes_Number  Obesity_Number  Physical_Inactivity_Number  \
# 0         0.093804        0.244366                    0.226902
# 1         0.080281        0.233255                    0.192324
# 2         0.131875        0.310643                    0.210651
# 3         0.105251        0.290052                    0.258667
# 4         0.108977        0.246804                    0.249198
#
#    sex and age_total population_65 years and over_sex ratio (males per 100 females)  \
# 0                                           0.001386
# 1                                           0.000416
# 2                                           0.002956
# 3                                           0.003573
# 4                                           0.001383
#
#    race_total population_one race  race_total population_two or more races  \
# 0                        0.981341                                 0.018659
# 1                        0.982836                                 0.017164
# 2                        0.986308                                 0.013692
# 3                        0.991699                                 0.008301
# 4                        0.983780                                 0.016220
#
#    race_total population_one race_1  race_total population_one race_white  \
# 0                          0.981341                              0.768786
# 1                          0.982836                              0.862662
# 2                          0.986308                              0.473819
# 3                          0.991699                              0.766547
# 4                          0.983780                              0.955052
#
#    race_total population_one race_black or african american  \
# 0                                           0.191395
# 1                                           0.094970
# 2                                           0.475758
# 3                                           0.222755
# 4                                           0.014954
#
#    race_total population_one race_american indian and alaska native  ...  \
# 0                                           0.002880                 ...
# 1                                           0.007314                 ...
# 2                                           0.002793                 ...
# 3                                           0.000355                 ...
# 4                                           0.002446                 ...
#
#    sex and age_total population_18 years and over_sex ratio (males per 100 females)  \
# 0                                           0.001668
# 1                                           0.000445
# 2                                           0.004495
# 3                                           0.005127
# 4                                           0.001658
#
#    sex and age_total population_65 years and over_1  \
# 0                                          0.145833
# 1                                          0.195404
# 2                                          0.179738
# 3                                          0.162516
# 4                                          0.177518
#
#    sex and age_total population_65 years and over_male  \
# 0                                           0.063188
# 1                                           0.090675
# 2                                           0.077729
# 3                                           0.072491
# 4                                           0.078758
#
#    sex and age_total population_65 years and over_female  male_over_18  \
# 0                                           0.082645          0.000009
# 1                                           0.104730          0.000002
# 2                                           0.102009          0.000021
# 3                                           0.090025          0.000024
# 4                                           0.098760          0.000008
#
#    female_over_18  CountyFIPS  race_total population  male_18_adj  \
# 0        0.000009        1001                  55200     0.479405
# 1        0.000002        1003                 208107     0.480847
# 2        0.000018        1005                  25782     0.536862
# 3        0.000021        1007                  22527     0.536042
# 4        0.000009        1009                  57645     0.488829
#
#    female_18_adj
# 0       0.520595
# 1       0.519153
# 2       0.463138
# 3       0.463958
# 4       0.511171
#
# [5 rows x 97 columns]

# %%
diabetes_rates.describe()
# Out:
#        Diabetes_Number  Obesity_Number  Physical_Inactivity_Number  \
# count      3112.000000     3112.000000                 3112.000000
# mean          0.092857        0.251666                    0.200861
# std           0.028097        0.044323                    0.044511
# min           0.019038        0.088946                    0.064949
# 25%           0.072169        0.223436                    0.170128
# 50%           0.089291        0.252390                    0.199036
# 75%           0.110175        0.280113                    0.231041
# max           0.224208        0.476788                    0.392285
#
#        sex and age_total population_65 years and over_sex ratio (males per 100 females)  \
# count                                        3112.000000
# mean                                            0.008463
# std                                             0.022489
# min                                             0.000008
# 25%                                             0.001186
# 50%                                             0.003179
# 75%                                             0.007626
# max                                             0.595175
#
#        race_total population_one race  \
# count                     3112.000000
# mean                         0.976059
# std                          0.019379
# min                          0.713126
# 25%                          0.971038
# 50%                          0.980119
# 75%                          0.986630
# max                          1.000000
#
#        race_total population_two or more races  \
# count                              3112.000000
# mean                                  0.023941
# std                                   0.019379
# min                                   0.000000
# 25%                                   0.013370
# 50%                                   0.019881
# 75%                                   0.028962
# max                                   0.286874
#
#        race_total population_one race_1  race_total population_one race_white  \
# count                       3112.000000                           3112.000000
# mean                           0.976059                              0.831107
# std                            0.019379                              0.167534
# min                            0.713126                              0.038912
# 25%                            0.971038                              0.767171
# 50%                            0.980119                              0.896086
# 75%                            0.986630                              0.950193
# max                            1.000000                              1.000000
#
#        race_total population_one race_black or african american  \
# count                                        3112.000000
# mean                                            0.090215
# std                                             0.144287
# min                                             0.000000
# 25%                                             0.006815
# 50%                                             0.022927
# 75%                                             0.101805
# max                                             0.874123
#
#        race_total population_one race_american indian and alaska native  ...  \
# count                                        3112.000000                 ...
# mean                                            0.019398                 ...
# std                                             0.076536                 ...
# min                                             0.000000                 ...
# 25%                                             0.001722                 ...
# 50%                                             0.003499                 ...
# 75%                                             0.008392                 ...
# max                                             0.924799                 ...
#
#        sex and age_total population_18 years and over_sex ratio (males per 100 females)  \
# count                                        3112.000000
# mean                                            0.009663
# std                                             0.023179
# min                                             0.000009
# 25%                                             0.001399
# 50%                                             0.003741
# 75%                                             0.009028
# max                                             0.525000
#
#        sex and age_total population_65 years and over_1  \
# count                                       3112.000000
# mean                                           0.183579
# std                                            0.045926
# min                                            0.037986
# 25%                                            0.154466
# 50%                                            0.180192
# 75%                                            0.208009
# max                                            0.555963
#
#        sex and age_total population_65 years and over_male  \
# count                                        3112.000000
# mean                                            0.084032
# std                                             0.023584
# min                                             0.015325
# 25%                                             0.069043
# 50%                                             0.081007
# 75%                                             0.095678
# max                                             0.268589
#
#        sex and age_total population_65 years and over_female  male_over_18  \
# count                                        3112.000000      3.112000e+03
# mean                                            0.099547      4.698359e-05
# std                                             0.023556      1.061852e-04
# min                                             0.022662      4.827863e-08
# 25%                                             0.085041      7.144686e-06
# 50%                                             0.098869      1.898416e-05
# 75%                                             0.112504      4.459395e-05
# max                                             0.287374      2.389957e-03
#
#        female_over_18    CountyFIPS  race_total population  male_18_adj  \
# count    3.112000e+03   3112.000000           3.112000e+03  3112.000000
# mean     4.576699e-05  30374.235219           1.036826e+05     0.497027
# std      9.812855e-05  15162.736031           3.313625e+05     0.028644
# min      5.075037e-08   1001.000000           2.280000e+02     0.414418
# 25%      7.439118e-06  18178.500000           1.122675e+04     0.482462
# 50%      1.927036e-05  29174.000000           2.613750e+04     0.491329
# 75%      4.440287e-05  45075.500000           6.847725e+04     0.502382
# max      1.996008e-03  56045.000000           1.009805e+07     0.805694
#
#        female_18_adj
# count    3112.000000
# mean        0.502973
# std         0.028644
# min         0.194306
# 25%         0.497618
# 50%         0.508671
# 75%         0.517538
# max         0.585582
#
# [8 rows x 97 columns]

# %% [markdown]
# ## Visualization and Plotting

# %% [markdown]
# We created numerous plots to help us get a handle on the data, including histograms, box and whisker plots, and scatterplots. Because you asked us to limit ourselves to 3 for this final notebook, we are including the 3 plots that we thought were helpful to give us a grasp of the patterns between diabetes prevalence and race, age, and gender.

# %% [markdown]
# ### Proportion of Age Group in County vs Proportion of Diabetes in County

# %%
ax1 = diabetes_rates.plot(kind='scatter', x='sex and age_total population_20 to 24 years', y='Diabetes_Number', color='r', label = "20 to 24")
ax2 = diabetes_rates.plot(kind='scatter', x='sex and age_total population_25 to 34 years', y='Diabetes_Number', color='coral', label = "25 to 34", ax=ax1)
ax3 = diabetes_rates.plot(kind='scatter', x='sex and age_total population_35 to 44 years', y='Diabetes_Number', color='gold', label = "35 to 44", ax=ax1)
ax4 = diabetes_rates.plot(kind='scatter', x='sex and age_total population_45 to 54 years', y='Diabetes_Number', color='greenyellow', label = "45 to 54", ax=ax1)
ax5 = diabetes_rates.plot(kind='scatter', x='sex and age_total population_55 to 59 years', y='Diabetes_Number', color='green', label = "55 to 59", ax=ax1)
ax6 = diabetes_rates.plot(kind='scatter', x='sex and age_total population_60 to 64 years', y='Diabetes_Number', color='aqua', label = "60 to 64", ax=ax1)
ax7 = diabetes_rates.plot(kind='scatter', x='sex and age_total population_65 to 74 years', y='Diabetes_Number', color='dodgerblue', label = "65 to 74", ax=ax1)

ax1.set_xlabel("Diabetes Rate in County")
ax1.set_ylabel("Proportion of Age Group in County")

print(ax1 == ax2 == ax3 == ax4 == ax5 == ax6)  # True
# Out:
# True

# %% [markdown]
# This plot seems to show that counties with a higher proportion of older people tend to have higher rates of diabetes. Note that the age structure of the population isn't controlled for here.

# %% [markdown]
# ### Proportion of "Sex" in County vs Proportion of Diabetes in County

# %%
ax1 = diabetes_rates.plot(kind='scatter', y='Diabetes_Number', x='male_18_adj', color='yellow', label = "Men")
ax2 = diabetes_rates.plot(kind='scatter', y='Diabetes_Number', x='female_18_adj', color='coral', label = "Women", ax=ax1)


ax1.set_xlabel("Diabetes Rate in County")
ax1.set_ylabel("Proportion Gender, age 18+, in County")
print(ax1 == ax2 )  # True
# Out:
# True

# %% [markdown]
# ### Proportion Race/Ethnic Group in County vs Proportion Diabetes in County

# %%
ax1 = diabetes_rates.plot(kind='scatter', x='race_total population_one race_white', y='Diabetes_Number', color='m', label = "white")
ax2 = diabetes_rates.plot(kind='scatter', x='race alone or in combination with one or more other races_total population_black or african american', y='Diabetes_Number', color='blue', label = "Black", ax=ax1)
ax3 = diabetes_rates.plot(kind='scatter', x='race alone or in combination with one or more other races_total population_asian', y='Diabetes_Number', color='cyan', label = "Asian", ax=ax1)
ax4 = diabetes_rates.plot(kind='scatter', x='hispanic or latino and race_total population_hispanic or latino (of any race)', y='Diabetes_Number', color='greenyellow', label = "Latinx", ax=ax1)

ax1.set_xlabel("Diabetes Rate in County")
ax1.set_ylabel("Proportion of Racial/Ethnic Group in County")
print(ax1 == ax2 == ax3 == ax4)  # True
# Out:
# True

# %% [markdown]
# ## Covariance and Correlation

# %% [markdown]
# Because we ran out of plots to show you, we'd also like to show you how the features in the provided data are correlated. For instance, you'll see that inactivity, obesity, and diabetes are each correlated.

# %%
diabetes_rates.cov(min_periods=1)
# Out:
#                                                     Diabetes_Number  \
# Diabetes_Number                                        7.894587e-04
# Obesity_Number                                         6.844165e-04
# Physical_Inactivity_Number                             7.392737e-04
# sex and age_total population_65 years and over_...    -2.835695e-05
# race_total population_one race                         5.848109e-05
# ...                                                             ...
# female_over_18                                        -1.561777e-07
# CountyFIPS                                            -1.663693e+01
# race_total population                                 -1.440395e+03
# male_18_adj                                           -6.470222e-05
# female_18_adj                                          6.470222e-05
#
#                                                     Obesity_Number  \
# Diabetes_Number                                       6.844165e-04
# Obesity_Number                                        1.964511e-03
# Physical_Inactivity_Number                            1.142120e-03
# sex and age_total population_65 years and over_...   -9.512606e-05
# race_total population_one race                        8.406574e-05
# ...                                                            ...
# female_over_18                                       -5.786064e-07
# CountyFIPS                                           -7.564394e+00
# race_total population                                -2.927693e+03
# male_18_adj                                           1.345118e-05
# female_18_adj                                        -1.345118e-05
#
#                                                     Physical_Inactivity_Number  \
# Diabetes_Number                                                   7.392737e-04
# Obesity_Number                                                    1.142120e-03
# Physical_Inactivity_Number                                        1.981217e-03
# sex and age_total population_65 years and over_...                2.350292e-05
# race_total population_one race                                    1.257372e-04
# ...                                                                        ...
# female_over_18                                                    3.963252e-08
# CountyFIPS                                                       -8.494275e+01
# race_total population                                            -3.085954e+03
# male_18_adj                                                      -3.285167e-06
# female_18_adj                                                     3.285167e-06
#
#                                                     sex and age_total population_65 years and over_sex ratio (males per 100 females)  \
# Diabetes_Number                                                                             -0.000028
# Obesity_Number                                                                              -0.000095
# Physical_Inactivity_Number                                                                   0.000024
# sex and age_total population_65 years and over_...                                           0.000506
# race_total population_one race                                                               0.000013
# ...                                                                                               ...
# female_over_18                                                                               0.000002
# CountyFIPS                                                                                   6.086437
# race_total population                                                                     -793.439867
# male_18_adj                                                                                  0.000117
# female_18_adj                                                                               -0.000117
#
#                                                     race_total population_one race  \
# Diabetes_Number                                                       5.848109e-05
# Obesity_Number                                                        8.406574e-05
# Physical_Inactivity_Number                                            1.257372e-04
# sex and age_total population_65 years and over_...                    1.273927e-05
# race_total population_one race                                        3.755635e-04
# ...                                                                            ...
# female_over_18                                                        1.381163e-07
# CountyFIPS                                                            2.844587e-02
# race_total population                                                -8.704795e+02
# male_18_adj                                                          -3.073089e-05
# female_18_adj                                                         3.073089e-05
#
#                                                     race_total population_two or more races  \
# Diabetes_Number                                                               -5.848109e-05
# Obesity_Number                                                                -8.406574e-05
# Physical_Inactivity_Number                                                    -1.257372e-04
# sex and age_total population_65 years and over_...                            -1.273927e-05
# race_total population_one race                                                -3.755635e-04
# ...                                                                                     ...
# female_over_18                                                                -1.381163e-07
# CountyFIPS                                                                    -2.844587e-02
# race_total population                                                          8.704795e+02
# male_18_adj                                                                    3.073089e-05
# female_18_adj                                                                 -3.073089e-05
#
#                                                     race_total population_one race_1  \
# Diabetes_Number                                                         5.848109e-05
# Obesity_Number                                                          8.406574e-05
# Physical_Inactivity_Number                                              1.257372e-04
# sex and age_total population_65 years and over_...                      1.273927e-05
# race_total population_one race                                          3.755635e-04
# ...                                                                              ...
# female_over_18                                                          1.381163e-07
# CountyFIPS                                                              2.844587e-02
# race_total population                                                  -8.704795e+02
# male_18_adj                                                            -3.073089e-05
# female_18_adj                                                           3.073089e-05
#
#                                                     race_total population_one race_white  \
# Diabetes_Number                                                                -0.001086
# Obesity_Number                                                                 -0.001323
# Physical_Inactivity_Number                                                     -0.000824
# sex and age_total population_65 years and over_...                              0.000353
# race_total population_one race                                                  0.000783
# ...                                                                                  ...
# female_over_18                                                                  0.000002
# CountyFIPS                                                                    313.502789
# race_total population                                                      -10752.608968
# male_18_adj                                                                     0.000244
# female_18_adj                                                                  -0.000244
#
#                                                     race_total population_one race_black or african american  \
# Diabetes_Number                                                                              0.001498
# Obesity_Number                                                                               0.002029
# Physical_Inactivity_Number                                                                   0.001846
# sex and age_total population_65 years and over_...                                          -0.000374
# race_total population_one race                                                               0.000280
# ...                                                                                               ...
# female_over_18                                                                              -0.000002
# CountyFIPS                                                                                -281.325010
# race_total population                                                                     3783.620609
# male_18_adj                                                                                 -0.000504
# female_18_adj                                                                                0.000504
#
#                                                     race_total population_one race_american indian and alaska native  \
# Diabetes_Number                                                                          1.816136e-05
# Obesity_Number                                                                           5.637231e-05
# Physical_Inactivity_Number                                                              -1.777244e-04
# sex and age_total population_65 years and over_...                                       1.074261e-04
# race_total population_one race                                                          -3.555640e-04
# ...                                                                                               ...
# female_over_18                                                                           4.355835e-07
# CountyFIPS                                                                              -1.415042e+01
# race_total population                                                                   -1.147206e+03
# male_18_adj                                                                              1.715344e-04
# female_18_adj                                                                           -1.715344e-04
#
#                                                     ...  \
# Diabetes_Number                                     ...
# Obesity_Number                                      ...
# Physical_Inactivity_Number                          ...
# sex and age_total population_65 years and over_...  ...
# race_total population_one race                      ...
# ...                                                 ...
# female_over_18                                      ...
# CountyFIPS                                          ...
# race_total population                               ...
# male_18_adj                                         ...
# female_18_adj                                       ...
#
#                                                     sex and age_total population_18 years and over_sex ratio (males per 100 females)  \
# Diabetes_Number                                                                             -0.000027
# Obesity_Number                                                                              -0.000097
# Physical_Inactivity_Number                                                                   0.000029
# sex and age_total population_65 years and over_...                                           0.000505
# race_total population_one race                                                               0.000019
# ...                                                                                               ...
# female_over_18                                                                               0.000002
# CountyFIPS                                                                                   8.642255
# race_total population                                                                     -902.587392
# male_18_adj                                                                                  0.000162
# female_18_adj                                                                               -0.000162
#
#                                                     sex and age_total population_65 years and over_1  \
# Diabetes_Number                                                                             0.000296
# Obesity_Number                                                                              0.000113
# Physical_Inactivity_Number                                                                  0.000482
# sex and age_total population_65 years and over_...                                          0.000240
# race_total population_one race                                                              0.000153
# ...                                                                                              ...
# female_over_18                                                                              0.000001
# CountyFIPS                                                                                 32.927748
# race_total population                                                                   -3226.821305
# male_18_adj                                                                                -0.000097
# female_18_adj                                                                               0.000097
#
#                                                     sex and age_total population_65 years and over_male  \
# Diabetes_Number                                                                          1.207522e-04
# Obesity_Number                                                                           2.752507e-05
# Physical_Inactivity_Number                                                               2.030408e-04
# sex and age_total population_65 years and over_...                                       1.586746e-04
# race_total population_one race                                                           6.355344e-05
# ...                                                                                               ...
# female_over_18                                                                           7.022972e-07
# CountyFIPS                                                                               1.752275e+01
# race_total population                                                                   -1.720473e+03
# male_18_adj                                                                              1.646465e-05
# female_18_adj                                                                           -1.646465e-05
#
#                                                     sex and age_total population_65 years and over_female  \
# Diabetes_Number                                                                          1.747535e-04
# Obesity_Number                                                                           8.515646e-05
# Physical_Inactivity_Number                                                               2.793159e-04
# sex and age_total population_65 years and over_...                                       8.103114e-05
# race_total population_one race                                                           8.933086e-05
# ...                                                                                               ...
# female_over_18                                                                           5.557732e-07
# CountyFIPS                                                                               1.540500e+01
# race_total population                                                                   -1.506348e+03
# male_18_adj                                                                             -1.139025e-04
# female_18_adj                                                                            1.139025e-04
#
#                                                     male_over_18  \
# Diabetes_Number                                    -1.489305e-07
# Obesity_Number                                     -5.281766e-07
# Physical_Inactivity_Number                          9.302973e-08
# sex and age_total population_65 years and over_...  2.300754e-06
# race_total population_one race                      1.135170e-07
# ...                                                          ...
# female_over_18                                      1.020195e-08
# CountyFIPS                                          4.225771e-02
# race_total population                              -4.375760e+00
# male_18_adj                                         5.839126e-07
# female_18_adj                                      -5.839126e-07
#
#                                                     female_over_18  \
# Diabetes_Number                                      -1.561777e-07
# Obesity_Number                                       -5.786064e-07
# Physical_Inactivity_Number                            3.963252e-08
# sex and age_total population_65 years and over_...    2.033852e-06
# race_total population_one race                        1.381163e-07
# ...                                                            ...
# female_over_18                                        9.629212e-09
# CountyFIPS                                            4.309822e-02
# race_total population                                -4.243632e+00
# male_18_adj                                           3.003803e-07
# female_18_adj                                        -3.003803e-07
#
#                                                       CountyFIPS  \
# Diabetes_Number                                    -1.663693e+01
# Obesity_Number                                     -7.564394e+00
# Physical_Inactivity_Number                         -8.494275e+01
# sex and age_total population_65 years and over_...  6.086437e+00
# race_total population_one race                      2.844587e-02
# ...                                                          ...
# female_over_18                                      4.309822e-02
# CountyFIPS                                          2.299086e+08
# race_total population                              -2.806758e+08
# male_18_adj                                        -4.936816e-01
# female_18_adj                                       4.936816e-01
#
#                                                     race_total population  \
# Diabetes_Number                                             -1.440395e+03
# Obesity_Number                                              -2.927693e+03
# Physical_Inactivity_Number                                  -3.085954e+03
# sex and age_total population_65 years and over_...          -7.934399e+02
# race_total population_one race                              -8.704795e+02
# ...                                                                   ...
# female_over_18                                              -4.243632e+00
# CountyFIPS                                                  -2.806758e+08
# race_total population                                        1.098011e+11
# male_18_adj                                                 -1.054610e+03
# female_18_adj                                                1.054610e+03
#
#                                                      male_18_adj  \
# Diabetes_Number                                    -6.470222e-05
# Obesity_Number                                      1.345118e-05
# Physical_Inactivity_Number                         -3.285167e-06
# sex and age_total population_65 years and over_...  1.170445e-04
# race_total population_one race                     -3.073089e-05
# ...                                                          ...
# female_over_18                                      3.003803e-07
# CountyFIPS                                         -4.936816e-01
# race_total population                              -1.054610e+03
# male_18_adj                                         8.205001e-04
# female_18_adj                                      -8.205001e-04
#
#                                                     female_18_adj
# Diabetes_Number                                      6.470222e-05
# Obesity_Number                                      -1.345118e-05
# Physical_Inactivity_Number                           3.285167e-06
# sex and age_total population_65 years and over_...  -1.170445e-04
# race_total population_one race                       3.073089e-05
# ...                                                           ...
# female_over_18                                      -3.003803e-07
# CountyFIPS                                           4.936816e-01
# race_total population                                1.054610e+03
# male_18_adj                                         -8.205001e-04
# female_18_adj                                        8.205001e-04
#
# [97 rows x 97 columns]

# %%
diabetes_rates.corr(method='pearson', min_periods=1)
# Out:
#                                                     Diabetes_Number  \
# Diabetes_Number                                            1.000000
# Obesity_Number                                             0.549577
# Physical_Inactivity_Number                                 0.591118
# sex and age_total population_65 years and over_...        -0.044877
# race_total population_one race                             0.107401
# ...                                                             ...
# female_over_18                                            -0.056645
# CountyFIPS                                                -0.039051
# race_total population                                     -0.154708
# male_18_adj                                               -0.080392
# female_18_adj                                              0.080392
#
#                                                     Obesity_Number  \
# Diabetes_Number                                           0.549577
# Obesity_Number                                            1.000000
# Physical_Inactivity_Number                                0.578920
# sex and age_total population_65 years and over_...       -0.095433
# race_total population_one race                            0.097870
# ...                                                            ...
# female_over_18                                           -0.133033
# CountyFIPS                                               -0.011256
# race_total population                                    -0.199340
# male_18_adj                                               0.010595
# female_18_adj                                            -0.010595
#
#                                                     Physical_Inactivity_Number  \
# Diabetes_Number                                                       0.591118
# Obesity_Number                                                        0.578920
# Physical_Inactivity_Number                                            1.000000
# sex and age_total population_65 years and over_...                    0.023479
# race_total population_one race                                        0.145766
# ...                                                                        ...
# female_over_18                                                        0.009074
# CountyFIPS                                                           -0.125859
# race_total population                                                -0.209228
# male_18_adj                                                          -0.002577
# female_18_adj                                                         0.002577
#
#                                                     sex and age_total population_65 years and over_sex ratio (males per 100 females)  \
# Diabetes_Number                                                                             -0.044877
# Obesity_Number                                                                              -0.095433
# Physical_Inactivity_Number                                                                   0.023479
# sex and age_total population_65 years and over_...                                           1.000000
# race_total population_one race                                                               0.029230
# ...                                                                                               ...
# female_over_18                                                                               0.921617
# CountyFIPS                                                                                   0.017849
# race_total population                                                                       -0.106472
# male_18_adj                                                                                  0.181693
# female_18_adj                                                                               -0.181693
#
#                                                     race_total population_one race  \
# Diabetes_Number                                                           0.107401
# Obesity_Number                                                            0.097870
# Physical_Inactivity_Number                                                0.145766
# sex and age_total population_65 years and over_...                        0.029230
# race_total population_one race                                            1.000000
# ...                                                                            ...
# female_over_18                                                            0.072629
# CountyFIPS                                                                0.000097
# race_total population                                                    -0.135554
# male_18_adj                                                              -0.055360
# female_18_adj                                                             0.055360
#
#                                                     race_total population_two or more races  \
# Diabetes_Number                                                                   -0.107401
# Obesity_Number                                                                    -0.097870
# Physical_Inactivity_Number                                                        -0.145766
# sex and age_total population_65 years and over_...                                -0.029230
# race_total population_one race                                                    -1.000000
# ...                                                                                     ...
# female_over_18                                                                    -0.072629
# CountyFIPS                                                                        -0.000097
# race_total population                                                              0.135554
# male_18_adj                                                                        0.055360
# female_18_adj                                                                     -0.055360
#
#                                                     race_total population_one race_1  \
# Diabetes_Number                                                             0.107401
# Obesity_Number                                                              0.097870
# Physical_Inactivity_Number                                                  0.145766
# sex and age_total population_65 years and over_...                          0.029230
# race_total population_one race                                              1.000000
# ...                                                                              ...
# female_over_18                                                              0.072629
# CountyFIPS                                                                  0.000097
# race_total population                                                      -0.135554
# male_18_adj                                                                -0.055360
# female_18_adj                                                               0.055360
#
#                                                     race_total population_one race_white  \
# Diabetes_Number                                                                -0.230673
# Obesity_Number                                                                 -0.178148
# Physical_Inactivity_Number                                                     -0.110549
# sex and age_total population_65 years and over_...                              0.093666
# race_total population_one race                                                  0.241059
# ...                                                                                  ...
# female_over_18                                                                  0.112788
# CountyFIPS                                                                      0.123413
# race_total population                                                          -0.193690
# male_18_adj                                                                     0.050818
# female_18_adj                                                                  -0.050818
#
#                                                     race_total population_one race_black or african american  \
# Diabetes_Number                                                                              0.369464
# Obesity_Number                                                                               0.317216
# Physical_Inactivity_Number                                                                   0.287397
# sex and age_total population_65 years and over_...                                          -0.115214
# race_total population_one race                                                               0.100154
# ...                                                                                               ...
# female_over_18                                                                              -0.123317
# CountyFIPS                                                                                  -0.128589
# race_total population                                                                        0.079136
# male_18_adj                                                                                 -0.121897
# female_18_adj                                                                                0.121897
#
#                                                     race_total population_one race_american indian and alaska native  \
# Diabetes_Number                                                                              0.008445
# Obesity_Number                                                                               0.016618
# Physical_Inactivity_Number                                                                  -0.052170
# sex and age_total population_65 years and over_...                                           0.062413
# race_total population_one race                                                              -0.239725
# ...                                                                                               ...
# female_over_18                                                                               0.057998
# CountyFIPS                                                                                  -0.012194
# race_total population                                                                       -0.045235
# male_18_adj                                                                                  0.078244
# female_18_adj                                                                               -0.078244
#
#                                                     ...  \
# Diabetes_Number                                     ...
# Obesity_Number                                      ...
# Physical_Inactivity_Number                          ...
# sex and age_total population_65 years and over_...  ...
# race_total population_one race                      ...
# ...                                                 ...
# female_over_18                                      ...
# CountyFIPS                                          ...
# race_total population                               ...
# male_18_adj                                         ...
# female_18_adj                                       ...
#
#                                                     sex and age_total population_18 years and over_sex ratio (males per 100 females)  \
# Diabetes_Number                                                                             -0.042219
# Obesity_Number                                                                              -0.094503
# Physical_Inactivity_Number                                                                   0.028347
# sex and age_total population_65 years and over_...                                           0.968349
# race_total population_one race                                                               0.043077
# ...                                                                                               ...
# female_over_18                                                                               0.941333
# CountyFIPS                                                                                   0.024590
# race_total population                                                                       -0.117516
# male_18_adj                                                                                  0.244367
# female_18_adj                                                                               -0.244367
#
#                                                     sex and age_total population_65 years and over_1  \
# Diabetes_Number                                                                             0.229002
# Obesity_Number                                                                              0.055356
# Physical_Inactivity_Number                                                                  0.235961
# sex and age_total population_65 years and over_...                                          0.232083
# race_total population_one race                                                              0.171775
# ...                                                                                              ...
# female_over_18                                                                              0.279157
# CountyFIPS                                                                                  0.047285
# race_total population                                                                      -0.212036
# male_18_adj                                                                                -0.074067
# female_18_adj                                                                               0.074067
#
#                                                     sex and age_total population_65 years and over_male  \
# Diabetes_Number                                                                              0.182226
# Obesity_Number                                                                               0.026332
# Physical_Inactivity_Number                                                                   0.193418
# sex and age_total population_65 years and over_...                                           0.299167
# race_total population_one race                                                               0.139052
# ...                                                                                               ...
# female_over_18                                                                               0.303463
# CountyFIPS                                                                                   0.049001
# race_total population                                                                       -0.220153
# male_18_adj                                                                                  0.024372
# female_18_adj                                                                               -0.024372
#
#                                                     sex and age_total population_65 years and over_female  \
# Diabetes_Number                                                                              0.264039
# Obesity_Number                                                                               0.081564
# Physical_Inactivity_Number                                                                   0.266401
# sex and age_total population_65 years and over_...                                           0.152963
# race_total population_one race                                                               0.195689
# ...                                                                                               ...
# female_over_18                                                                               0.240441
# CountyFIPS                                                                                   0.043131
# race_total population                                                                       -0.192987
# male_18_adj                                                                                 -0.168811
# female_18_adj                                                                                0.168811
#
#                                                     male_over_18  \
# Diabetes_Number                                        -0.049918
# Obesity_Number                                         -0.112225
# Physical_Inactivity_Number                              0.019683
# sex and age_total population_65 years and over_...      0.963458
# race_total population_one race                          0.055164
# ...                                                          ...
# female_over_18                                          0.979093
# CountyFIPS                                              0.026246
# race_total population                                  -0.124362
# male_18_adj                                             0.191975
# female_18_adj                                          -0.191975
#
#                                                     female_over_18  \
# Diabetes_Number                                          -0.056645
# Obesity_Number                                           -0.133033
# Physical_Inactivity_Number                                0.009074
# sex and age_total population_65 years and over_...        0.921617
# race_total population_one race                            0.072629
# ...                                                            ...
# female_over_18                                            1.000000
# CountyFIPS                                                0.028966
# race_total population                                    -0.130509
# male_18_adj                                               0.106865
# female_18_adj                                            -0.106865
#
#                                                     CountyFIPS  \
# Diabetes_Number                                      -0.039051
# Obesity_Number                                       -0.011256
# Physical_Inactivity_Number                           -0.125859
# sex and age_total population_65 years and over_...    0.017849
# race_total population_one race                        0.000097
# ...                                                        ...
# female_over_18                                        0.028966
# CountyFIPS                                            1.000000
# race_total population                                -0.055863
# male_18_adj                                          -0.001137
# female_18_adj                                         0.001137
#
#                                                     race_total population  \
# Diabetes_Number                                                 -0.154708
# Obesity_Number                                                  -0.199340
# Physical_Inactivity_Number                                      -0.209228
# sex and age_total population_65 years and over_...              -0.106472
# race_total population_one race                                  -0.135554
# ...                                                                   ...
# female_over_18                                                  -0.130509
# CountyFIPS                                                      -0.055863
# race_total population                                            1.000000
# male_18_adj                                                     -0.111109
# female_18_adj                                                    0.111109
#
#                                                     male_18_adj  female_18_adj
# Diabetes_Number                                       -0.080392       0.080392
# Obesity_Number                                         0.010595      -0.010595
# Physical_Inactivity_Number                            -0.002577       0.002577
# sex and age_total population_65 years and over_...     0.181693      -0.181693
# race_total population_one race                        -0.055360       0.055360
# ...                                                         ...            ...
# female_over_18                                         0.106865      -0.106865
# CountyFIPS                                            -0.001137       0.001137
# race_total population                                 -0.111109       0.111109
# male_18_adj                                            1.000000      -1.000000
# female_18_adj                                         -1.000000       1.000000
#
# [97 rows x 97 columns]

# %%
diabetes_rates.shape
# Out:
# (3112, 97)

# %% [markdown]
# ## 3: Prepare to Fit Model

# %% [markdown]
# ### 3.1: Data Cleaning

# %% [markdown]
# diabetes_normalize = diabetes_normalize.drop(['County', 'State'], axis = 1)
# diabetes_normalize.head()

# %%
np.nanquantile(diabetes_rates['Diabetes_Number'], q=0.25)
# Out:
# 0.07216936122629641

# %%
np.percentile(diabetes_rates['Diabetes_Number'], q=0.10)
# Out:
# 0.02929342417130693

# %%
np.nanquantile(diabetes_rates['Diabetes_Number'], q=0.75)

diabetes_rates['diabetes_90th'] = np.where(diabetes_rates['Diabetes_Number'] > np.percentile(mydata_norm['Diabetes_Number'], q=0.75), 1, 0)
mydata_norm = mydata_norm.dropna(axis=0, how='any')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-3115421c2d7b> in <module>
#       1 np.nanquantile(diabetes_rates['Diabetes_Number'], q=0.75)
#       2
# ----> 3 diabetes_rates['diabetes_90th'] = np.where(diabetes_rates['Diabetes_Number'] > np.percentile(mydata_norm['Diabetes_Number'], q=0.75), 1, 0)
#       4 mydata_norm = mydata_norm.dropna(axis=0, how='any')
#       5
#
# NameError: name 'mydata_norm' is not defined

# %% [markdown]
# ### 3.2: Partition Data

# %% [markdown]
# #### Train/Test/Validation Split

# %%
X = diabetes_rates.drop(['Diabetes_Number',], axis = 1)
y = diabetes_rates['Diabetes_Number']
X.head()

# %%
from sklearn.model_selection import train_test_split 

# set the random seed
np.random.seed(10)

# split the data
# train_test_split returns 4 values: X_train, X_test, y_train, y_test

X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    train_size=0.80, test_size=0.20)

# %%
print("Dimensions of Dataframe are", X.shape)

# %% [markdown]
# #### Validation Set

# %%
# split the data
# Returns 4 values: X_train, X_validate, y_train, y_validate

X_train, X_validate, y_train, y_validate = train_test_split(X_train, y_train,
                                                    train_size=0.75, test_size=0.25)

# %%
print("Shape of X train is", X_train.shape)
print("Shape of y_train is", y_train.shape)
print("Shape of X_test is", X_test.shape)
print("Shape of y_test is", y_test.shape)

# %% [markdown]
# ### 3.3: Feature Selection

# %%
print(X_train.columns)

# %% [markdown]
# ## 4: Train Models

# %% [markdown]
# ### 4.1: Model Description
#
# A. Choose 5 different machine learning techniques. See available ones in the
# scikit-learn documentation. 2.Detail the basic logic and assumptions underlying each model, its pros/cons,and why it is a plausible choice for this problem.
# 1. Linear Regression
# 2. Ridge Regression
# 3. Lasso Regression
# 4.
# 5.
#
# B. Detail the basic logic and assumptions underlying each model, its pros/cons,and why it is a plausible choice for this problem.

# %% [markdown]
# ### 4.2 Train Models

# %%
# create a model
lin_reg = LinearRegression(normalize=True)

# fit the model
lin_model = lin_reg.fit(X_train, y_train)

# %%
print(lin_model.coef_)
print(lin_model.intercept_)

# %%
# predict the number of riders
lin_pred = lin_model.predict(X_validate)

# plot the residuals on a scatter plot
plt.scatter(y_validate, lin_pred)
plt.title('Linear Model (OLS) Predicted v. Actual')
plt.xlabel('actual value')
plt.ylabel('predicted value')
plt.show()

# %%
def rmse(pred, actual):
    return np.sqrt(np.mean((pred - actual) ** 2))

# %%
rmse(lin_pred, y_validate)

# %% [markdown]
# #### Ridge Regression

# %%
# make and fit a Ridge regression model
ridge_reg = Ridge() 
ridge_model = ridge_reg.fit(X_train, y_train)
ridge_reg_data = pd.DataFrame([ridge_model.coef_, X.columns]).T
ridge_reg_data.columns = ['Coefficient', 'Feature']

# %%
# use the model to make predictions
ridge_pred = ridge_model.predict(X_validate)

# plot the predictions
plt.scatter(y_validate, ridge_pred)
plt.title('Ridge Model')
plt.xlabel('actual values')
plt.ylabel('predicted values')
plt.show()

# %%
# calculate the rmse for the Ridge model
rmse(ridge_pred, y_validate)

# %%
# create and fit the model
lasso_reg = Lasso(max_iter=10000) #initialize the model, add a hyperparameter 

lasso_model = lasso_reg.fit(X_train, y_train) #fit the model
lasso_reg_data = pd.DataFrame([lasso_model.coef_, X.columns]).T #save it in this dataframe
lasso_reg_data.columns = ['Coefficient', 'Feature']

# %%
# use the model to make predictions
lasso_pred = lasso_model.predict(X_validate)

# plot the predictions
plt.scatter(y_validate, lasso_pred)
plt.title('LASSO Model')
plt.xlabel('actual values')
plt.ylabel('predicted values')
plt.show()

# %%
# calculate the rmse for the LASSO model
rmse(lasso_pred, y_validate)

# %%
param_grid = {'fit_intercept': ['True', 'False'],
              'normalize': ['True', 'False']}

lin_grid_reg = GridSearchCV(lin_reg, param_grid, cv=3, iid=False)
lin_grid_reg.fit(X_train, y_train)

best_index = np.argmax(lin_grid_reg.cv_results_["mean_test_score"])
best_lin_pred = lin_grid_reg.best_estimator_.predict(X_validate)

print(lin_grid_reg.cv_results_["params"][best_index])
print('Best CV R^2:', max(lin_grid_reg.cv_results_["mean_test_score"]))
print('Validation R^2:', lin_grid_reg.score(X_validate, y_validate))
print('Validation RMSE', rmse(best_lin_pred, y_validate))

# %%
param_grid = {'alpha': np.arange(.1, 1, .1),
               'normalize': ['True', 'False'],
             'fit_intercept': ['True', 'False'],
             'solver': ['auto', 'svd', 'cholesky', 'lsqr']}

ridge_grid_reg = GridSearchCV(ridge_reg, param_grid, cv=3, iid=False)
ridge_grid_reg.fit(X_train, y_train)

best_index = np.argmax(ridge_grid_reg.cv_results_["mean_test_score"])
best_ridge_pred = ridge_grid_reg.best_estimator_.predict(X_validate)

print(ridge_grid_reg.cv_results_["params"][best_index])
print('Best CV R^2:', max(ridge_grid_reg.cv_results_["mean_test_score"]))
print('Validation R^2:', ridge_grid_reg.score(X_validate, y_validate))
print('Validation RMSE', rmse(best_ridge_pred, y_validate))

# %%
param_grid = {'alpha': np.arange(.1, 1, .1),
               'normalize': ['True', 'False'],
             'fit_intercept': ['True', 'False'],
             'selection': ['cyclic', 'random']}

lasso_grid_reg = GridSearchCV(lasso_reg, param_grid, cv=3, iid=False)
lasso_grid_reg.fit(X_train, y_train)

best_index = np.argmax(lasso_grid_reg.cv_results_["mean_test_score"])
best_lasso_pred = lasso_grid_reg.best_estimator_.predict(X_validate)

print(lasso_grid_reg.cv_results_["params"][best_index])
print('Best CV R^2:', max(lasso_grid_reg.cv_results_["mean_test_score"]))
print('Validation R^2:', lasso_grid_reg.score(X_validate, y_validate))
print('Validation RMSE', rmse(best_lasso_pred, y_validate))

# %% [markdown]
# Policymakers, you included a few trenchant questions in your instructions, which we answer below:

# %% [markdown]
# #### What is bias-variance tradeoff. Why is it relevant to machine learning problems like this one?

# %% [markdown]
# The bias-variance tradeoff refers to a difficulty we face in building statistical models. When models are made to fit very closely to the data, often using a lot of different features or variables in the process, this introduces a lot of variance, or flexibility of fit. The upside of high dimensionality models is that they are very accurate to the training data and they have little bias.  But because of their flexibility, high dimensionality models risk measuring noise in the data and mistaking it for signal. This problem is referred to as overfitting.
#
# Models with lower dimensionality tend to be less accurate and more rigid, or biased. Low dimension models are likelier than high dimension models to underfit data. When choosing an appropriate machine learning model, we must strike a balance between a model that is too biased/rigid and a model that is too noisy/flexible. This is the bias-variance tradeoff.
#
# In traditional regression applications, scientists are often most interested in accurately and unbiasedly capturing any existing relationship in their data. But in machine learning, we are looking to predict future values of our outcome based on the body of data we’ve amassed. A model that hews too closely to the data on which it was trained is less likely to make accurate predictions. In machine learning, therefore, it’s vital that we strike the right balance between capturing variance and avoiding overfitting.

# %% [markdown]
# #### Define overfitting, and why it matters for machine learning. How can we address it?

# %% [markdown]
# Overfitting occurs when a model is so precisely matched to the training dataset that the model perceives variance in the sample as part of the underlying relationship between the independent and dependent variables. Overfitting is particularly problematic for machine learning applications, because a model that has been overfit (overfitted?) will try to predict future values of the dependent variable that match with the variance or noise in the training data. This means that overfit models will be less successful at prediction, and prediction is the whole point of machine learning.
#
# We can address overfitting through the use of regularizing techniques like Ridge regression and LASSO. These help us to avoid overfitting by shrinking or eliminating coefficients in our model with low values. This reduces the overall number of dimensions in the model, pushing the balance away from overfitting.

# %% [markdown]
# #### Discuss your Analysis in 2-3 Paragraphs. Discuss your findings and recommendations. Which counties or regions would you prioritize for the pilot program? Would your answers change based on whether you want to take into account certain features such as the race, gender, or age composition in the county? How confident would you be deploying this sort of model in a real-world application, why or why not?

# %% [markdown]
# A few caveats: Our predictions are made based on known (diagnosed) diabetes cases. However, in the United States today, many people are unable to access adequate medical care, including diabetes diagnosis and treatment. If diabetes is more common among populations with lesser access to medical care, this gives us greater reason to believe our measurement of diabetes prevalence is flawed.
#
# The data provided do not tell us the demographics (age, gender, race, education, etc.) of the people who have been diagnosed with diabetes. This means that rather than directly capturing that, for instance, it is Asian women over age 70 with the highest prevalence of diabetes, we could only see that counties with a higher proportion of Asian women over age 70 also have a higher proportion of diabetes cases. We recommend analysis with data at a more granular level before spending billions of taxpayer dollars.
